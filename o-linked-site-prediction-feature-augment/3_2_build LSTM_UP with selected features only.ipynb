# %%
# '''
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }

# setInterval(ConnectButton,60000);
# '''

# from google.colab import drive
# from os import chdir

# drive.mount('/content/drive')
# project_path = '/content/drive/MyDrive/Gproject/o-linked-site-prediction-feature-augment'
# chdir(project_path)

# %%
import os
import numpy as np
import pandas as pd

# set seed for the reproducible result
SEED = 42

# %%
data_dir = './data/integrated_features' # we will get names from the augmented proteins
protein_names = [x.split('.')[0] for x in os.listdir(data_dir) if x.split('.')[1] == 'csv'] # get protein name list to be processed for building machine learning models
print('the number of initial proteins:', len(protein_names))
print(protein_names[:10])
# Out:
# the number of initial proteins: 104
# ['A2ABU4', 'A2AHJ4', 'A2AKB9', 'A2AQ25', 'E9Q1P8', 'E9Q5G3', 'O08537', 'O09061', 'O35303', 'O70263']

# %% [markdown]
# ## hyper parameter optimization by K-fold cross-validation

# %%
import tensorflow as tf
import keras
from keras.optimizers import Adam
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import KFold

import time
from IPython.display import clear_output

from ml_models import *

epochs = 1000
from keras.callbacks import EarlyStopping
patience = 30
callbacks = [EarlyStopping(patience=patience, restore_best_weights=True, monitor='val_loss')]

test_size = 0.2

# %% [markdown]
# ### set initial parameters

# %%
from functions import *

# %%
initial_params = default_params.copy()
initial_params.update({
    'window_size'    : 10
    })

print('initial parameters')
for key, value in initial_params.items():
    print(f'{key:<14} : {value}')

search_space = {
    'rnn_layers'    : [2, 3, 4, 5],
    'dnn_layers'    : [2, 3, 4, 5],
}
# Out:
# initial parameters
# rnn_layers     : 1
# rnn_neurons    : 64
# dnn_layers     : 3
# dnn_neurons    : 64
# activation     : softmax
# loss           : categorical_crossentropy
# metrics        : accuracy
# optimizer_type : Adam
# learning_rate  : 0.001
# regularizer    : {'input': None, 'hidden': None, 'bias': None}
# window_size    : 10

# %%
ratio_list = [0.05, 0.10, 0.20, 0.40, 0.80]
regularizer_list = [
    {'input': 'L21_0.00001', 'hidden': None,          'bias': None},
    {'input': 'L21_0.00001', 'hidden': 'L21_0.00001', 'bias': None},
    {'input': 'L1_0.0001',   'hidden': None,          'bias': None},
    {'input': 'L1_0.0001',   'hidden': 'L1_0.0001',   'bias': None},
]
yes_no = ['WITH', 'NO']

# %%
model_update  = False

keras.utils.set_random_seed(SEED)
tf.config.experimental.enable_op_determinism()
verbose = 0

search_terms = ['0A', '5A', '10A', '15A', '20A', '25A']
model_id = 1
ALL_METRICS = []

for yn in yes_no:
    for ratio in ratio_list:
        for regularizer in regularizer_list:
            METRICs = []
            METRIC_MEAN = []
            
            weights = pd.read_csv(f'./weights/SLSTM_UP_AUGMENT_KFOLD_4_64_3_64_Adam_0.001_{regularizer.get("input")}_{regularizer.get("hidden")}_None_10_(11528, 21, 518).csv', 
                                index_col=0, names=['weights'])
            selected_features = weights.sort_values(by = 'weights', ascending = False).iloc[ : int(len(weights) * ratio)]
            selected_features = [x for x in selected_features.weights.index if any(term in x for term in search_terms)]
            
            model_type = f'SELECTED_{yn}_SEQ_{regularizer.get("input")}_{regularizer.get("hidden")}'
            
            # set input features
            x_cts = selected_features
            x_cat = ['residue'] if yn == 'WITH' else []
            x_var = x_cts + x_cat
            
            # set output feature
            y_cts = []
            y_cat = ['positivity']
            y_var = y_cts + y_cat
            
            params = initial_params.copy()
            
            data_x = []
            data_y = []
            for name in protein_names:
                data = pd.read_csv(f'./data/integrated_features/{name}.csv')
                ST_idx = np.where((data['residue'] == 'S') | (data['residue'] == 'T'))[0]
                
                # get X dataset
                x_onehot = get_onehots(data[x_var], columns = x_cat)
                x_features = list(x_onehot.columns)
                
                # get Y dataset
                y_onehot = get_onehots(data[y_var], columns = y_cat)
                y_labels = list(y_onehot.columns)
                
                for idx in ST_idx:
                    window_x = np.array(get_window(x_onehot, idx, params['window_size']))
                    label_y  = np.array(y_onehot.iloc[idx])
                    
                    data_x.append(window_x)
                    data_y.append(label_y)
                    
            model = LSTM_CLS(data_x.shape[1], data_x.shape[-1], data_y.shape[-1], params) # I don't know why, but this row is helping producing the same training result of a neural network
            
            splitter = StratifiedShuffleSplit(n_splits = 1, test_size = test_size, random_state = SEED)
            train_idx, test_idx = list(splitter.split(data_x, data_y))[0]
            
            train_x = data_x[train_idx]
            train_y = data_y[train_idx]
            
            test_x = data_x[test_idx]
            test_y = data_y[test_idx]
            
            train_x, test_x = data_scaling(train_x, test_x)
            
            for param_name, space in search_space.items():
                for point in space:
                    clear_output(wait=True)
                    if ALL_METRICS:
                        display(pd.concat(ALL_METRICS, axis=0))
                    else:
                        display(ALL_METRICS)
                    display(METRIC_MEAN)
                    params[param_name] = point
                            
                    print('data x shape:', data_x.shape)
                    print('data y shape:', data_y.shape)
                    print('class y counts:', data_y.sum(0))
                    print(f'class y ratio: {(data_y.sum(0)/len(data_y)).round(4)}')
                    
                    splitter_kf = KFold(n_splits = 5)
                    
                    for cv_idx, (train_idx_kf, test_idx_kf) in enumerate(splitter_kf.split(train_x, train_y)):
                        train_x_kf, train_y_kf = train_x[train_idx_kf], train_y[train_idx_kf]
                        test_x_kf, test_y_kf   = train_x[test_idx_kf],  train_y[test_idx_kf]
                        
                        # up-sample the training dataset
                        train_x_kf, train_y_kf = upsample_data(train_x_kf, train_y_kf) 
                        
                        model = LSTM_CLS(data_x.shape[1], data_x.shape[-1], data_y.shape[-1], params) 
                        model_name = name_model(f'{model_type}_KFOLD', params)
                        
                        model_folder  = f'./models/{model_name}_{data_x.shape}'
                        if not os.path.exists(model_folder):
                            os.makedirs(model_folder)
                        model_path    = f'{model_folder}/{cv_idx}.h5'
                        metric_path   = f'{model_folder}/{cv_idx}.csv'
                        
                        
                        if not os.path.exists(model_path) or model_update:
                            time_start = time.time()
                            history = model.fit(train_x_kf, train_y_kf, verbose=verbose, 
                                                epochs = 10000, callbacks = callbacks,
                                                validation_data = (test_x_kf, test_y_kf))
                            time_end = time.time()
                            training_time = round((time_end - time_start)/60, 3)
                            
                            model.save_weights(model_path)
                            
                            test_loss, accuracy, precision, recall, f1 = metrics_classification(model, test_x, test_y)
                            model_metrics = {
                                'model_id' : model_id,
                                'cv_idx'   : cv_idx,
                                **{f'train_{x}': train_x.shape[x] for x in range(len(train_x.shape))},
                                'train_y'     : train_y.shape[-1],
                                'test_size'   : test_x.shape[0],
                                **params,
                                'regularizer_input' : params['regularizer']['input'],
                                'regularizer_hidden' : params['regularizer']['hidden'],
                                'regularizer_bias' : params['regularizer']['bias'],
                                'training_time': training_time,
                                'test_loss': test_loss,
                                'accuracy': accuracy,
                                **{f'precision_{x}': precision[x] for x in range(len(precision))},
                                **{f'recall_{x}'   : recall[x] for x in range(len(recall))},
                                **{f'f1_{x}'       : f1[x] for x in range(len(f1))}}
                            
                            model_metrics = pd.DataFrame([model_metrics]).drop(['activation', 'loss', 'metrics', 'optimizer_type', 'regularizer'], axis=1)
                            model_metrics.to_csv(metric_path, index=False)
                            
                        else:
                            model.load_weights(model_path)
                            model_metrics = pd.read_csv(metric_path, header=0)
                            
                        print(f'f1 score: {model_metrics.f1_1[0]}')
                        
                        model_metrics['model_id'] = model_id
                        METRICs.append(model_metrics)
                    
                    METRIC_MEAN = pd.concat(METRICs).groupby('model_id').mean()
                    model_id += 1
                    
                if param_name in ['learning_rate']: # for float-type parameters
                    best_value = float(METRIC_MEAN.sort_values('f1_1', ascending=False).iloc[0][param_name])
                    params[param_name] = best_value
                    
                else: # for int-type parameters
                    best_value = int(METRIC_MEAN.sort_values('f1_1', ascending=False).iloc[0][param_name])
                    params[param_name] = best_value
            
            ALL_METRICS.append(METRIC_MEAN.sort_values('f1_1', ascending=False).iloc[[0]])
# Out:
#           cv_idx  train_0  train_1  train_2  train_y  test_size  rnn_layers  \
# model_id
# 8            2.0    400.0     21.0     38.0      2.0      100.0         5.0
# 13           2.0    400.0     21.0     41.0      2.0      100.0         5.0
#
#           rnn_neurons  dnn_layers  dnn_neurons  ...  regularizer_bias  \
# model_id                                        ...
# 8                64.0         5.0         64.0  ...               NaN
# 13               64.0         2.0         64.0  ...               NaN
#
#           training_time  test_loss  accuracy  precision_0  precision_1  \
# model_id
# 8                0.1736   0.223039      95.6       99.380        7.500
# 13               0.1816   0.386105      86.6       99.794        6.044
#
#           recall_0  recall_1    f1_0    f1_1
# model_id
# 8           96.162      40.0  97.722  12.444
# 13          86.668      80.0  92.544  11.034
#
# [2 rows x 24 columns]
#           cv_idx  train_0  train_1  train_2  train_y  test_size  rnn_layers  \
# model_id
# 17           2.0    400.0     21.0     43.0      2.0      100.0         2.0
#
#           rnn_neurons  dnn_layers  dnn_neurons  ...  window_size  \
# model_id                                        ...
# 17               64.0         3.0         64.0  ...         10.0
#
#           training_time  test_loss  accuracy  precision_0  precision_1  \
# model_id
# 17               0.0856   0.487073      78.2       98.982         0.87
#
#           recall_0  recall_1    f1_0   f1_1
# model_id
# 17           78.79      20.0  87.572  1.666
#
# [1 rows x 21 columns]
# data x shape: (500, 21, 43)
# data y shape: (500, 2)
# class y counts: [494   6]
# class y ratio: [0.988 0.012]
# f1 score: 0.0
# f1 score: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [37], in <cell line: 11>()
#     106 if not os.path.exists(model_path) or model_update:
#     107     time_start = time.time()
# --> 108     history = model.fit(train_x_kf, train_y_kf, verbose=verbose,
#     109                         epochs = 1, callbacks = callbacks,
#     110                         validation_data = (test_x_kf, test_y_kf))
#     111     time_end = time.time()
#     112     training_time = round((time_end - time_start)/60, 3)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\def_function.py:980, in Function._call(self, *args, **kwds)
#     976     pass  # Fall through to cond-based initialization.
#     977   else:
#     978     # Lifting succeeded, so variables are initialized and we can run the
#     979     # stateless function.
# --> 980     return self._stateless_fn(*args, **kwds)
#     981 else:
#     982   _, _, filtered_flat_args = (
#     983       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     984           *args, **kwds))
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\function.py:2452, in Function.__call__(self, *args, **kwargs)
#    2449 """Calls a graph function specialized to the inputs."""
#    2450 with self._lock:
#    2451   (graph_function,
# -> 2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\function.py:2711, in Function._maybe_define_function(self, args, kwargs)
#    2708   cache_key = self._function_cache.generalize(cache_key)
#    2709   (args, kwargs) = cache_key._placeholder_value()  # pylint: disable=protected-access
# -> 2711 graph_function = self._create_graph_function(args, kwargs)
#    2712 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    2713                          graph_function)
#    2715 return graph_function, filtered_flat_args
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\function.py:2627, in Function._create_graph_function(self, args, kwargs)
#    2622 missing_arg_names = [
#    2623     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2624 ]
#    2625 arg_names = base_arg_names + missing_arg_names
#    2626 graph_function = ConcreteFunction(
# -> 2627     func_graph_module.func_graph_from_py_func(
#    2628         self._name,
#    2629         self._python_function,
#    2630         args,
#    2631         kwargs,
#    2632         self.input_signature,
#    2633         autograph=self._autograph,
#    2634         autograph_options=self._autograph_options,
#    2635         arg_names=arg_names,
#    2636         capture_by_value=self._capture_by_value),
#    2637     self._function_attributes,
#    2638     spec=self.function_spec,
#    2639     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2640     # scope. This is not the default behavior since it gets used in some
#    2641     # places (like Keras) where the FuncGraph lives longer than the
#    2642     # ConcreteFunction.
#    2643     shared_func_graph=False)
#    2644 return graph_function
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\func_graph.py:1141, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1138 else:
#    1139   _, original_func = tf_decorator.unwrap(python_func)
# -> 1141 func_outputs = python_func(*func_args, **func_kwargs)
#    1143 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1144 # TensorArrays and `None`s.
#    1145 func_outputs = nest.map_structure(
#    1146     convert, func_outputs, expand_composites=True)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\def_function.py:677, in Function._defun_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     673 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     674   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     675   # the function a weak reference to itself to avoid a reference cycle.
#     676   with OptionalXlaContext(compile_with_xla):
# --> 677     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     678   return out
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\func_graph.py:1116, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1114 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1115 try:
# -> 1116   return autograph.converted_call(
#    1117       original_func,
#    1118       args,
#    1119       kwargs,
#    1120       options=autograph.ConversionOptions(
#    1121           recursive=True,
#    1122           optional_features=autograph_options,
#    1123           user_requested=True,
#    1124       ))
#    1125 except Exception as e:  # pylint:disable=broad-except
#    1126   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_file92tzyux2.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\keras\engine\training.py:1040, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1037   run_step = tf.function(
#    1038       run_step, jit_compile=True, reduce_retracing=True)
#    1039 data = next(iterator)
# -> 1040 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1041 outputs = reduce_per_replica(
#    1042     outputs, self.distribute_strategy, reduction='first')
#    1043 return outputs
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1312, in StrategyBase.run(***failed resolving arguments***)
#    1307 with self.scope():
#    1308   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1309   # applied when the caller is also in Eager mode.
#    1310   fn = autograph.tf_convert(
#    1311       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1312   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2888, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2886   kwargs = {}
#    2887 with self._container_strategy().scope():
# -> 2888   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3689, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3687 def _call_for_each_replica(self, fn, args, kwargs):
#    3688   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3689     return fn(*args, **kwargs)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\autograph\impl\api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\keras\engine\training.py:1030, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1029 def run_step(data):
# -> 1030   outputs = model.train_step(data)
#    1031   # Ensure counter is updated only if `train_step` succeeds.
#    1032   with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\keras\engine\training.py:893, in Model.train_step(self, data)
#     891 self._validate_target_and_loss(y, loss)
#     892 # Run backwards pass.
# --> 893 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     894 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:537, in OptimizerV2.minimize(self, loss, var_list, grad_loss, name, tape)
#     506 def minimize(self, loss, var_list, grad_loss=None, name=None, tape=None):
#     507   """Minimize `loss` by updating `var_list`.
#     508
#     509   This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     535
#     536   """
# --> 537   grads_and_vars = self._compute_gradients(
#     538       loss, var_list=var_list, grad_loss=grad_loss, tape=tape)
#     539   return self.apply_gradients(grads_and_vars, name=name)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:590, in OptimizerV2._compute_gradients(self, loss, var_list, grad_loss, tape)
#     588 var_list = tf.nest.flatten(var_list)
#     589 with tf.name_scope(self._name + "/gradients"):
# --> 590   grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     592 self._assert_valid_dtypes([
#     593     v for g, v in grads_and_vars
#     594     if g is not None and v.dtype != tf.resource
#     595 ])
#     597 return grads_and_vars
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:471, in OptimizerV2._get_gradients(self, tape, loss, var_list, grad_loss)
#     469 def _get_gradients(self, tape, loss, var_list, grad_loss=None):
#     470   """Called in `minimize` to compute gradients from loss."""
# --> 471   grads = tape.gradient(loss, var_list, grad_loss)
#     472   return list(zip(grads, var_list))
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\backprop.py:1100, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1094   output_gradients = (
#    1095       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1096           output_gradients))
#    1097   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1098                       for x in output_gradients]
# -> 1100 flat_grad = imperative_grad.imperative_grad(
#    1101     self._tape,
#    1102     flat_targets,
#    1103     flat_sources,
#    1104     output_gradients=output_gradients,
#    1105     sources_raw=flat_sources_raw,
#    1106     unconnected_gradients=unconnected_gradients)
#    1108 if not self._persistent:
#    1109   # Keep track of watched variables before setting tape to None
#    1110   self._watched_variables = self._tape.watched_variables()
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\function.py:750, in _DelayedRewriteGradientFunctions._backward.<locals>._backward_function(*args)
#     748 def _backward_function(*args):
#     749   call_op = outputs[0].op
# --> 750   return self._rewrite_forward_and_call_backward(call_op, *args)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\function.py:666, in _DelayedRewriteGradientFunctions._rewrite_forward_and_call_backward(self, op, *doutputs)
#     664 def _rewrite_forward_and_call_backward(self, op, *doutputs):
#     665   """Add outputs to the forward call and feed them to the grad function."""
# --> 666   forward_function, backwards_function = self.forward_backward(len(doutputs))
#     667   if not backwards_function.outputs:
#     668     return backwards_function.structured_outputs
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\function.py:599, in _DelayedRewriteGradientFunctions.forward_backward(self, num_doutputs)
#     597 if forward_backward is not None:
#     598   return forward_backward
# --> 599 forward, backward = self._construct_forward_backward(num_doutputs)
#     600 self._cached_function_pairs[num_doutputs] = (forward, backward)
#     601 return forward, backward
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\function.py:642, in _DelayedRewriteGradientFunctions._construct_forward_backward(self, num_doutputs)
#     639 with self._func_graph.as_default():
#     640   backwards_graph = func_graph_module.FuncGraph(
#     641       _backward_name(self._func_graph.name))
# --> 642   func_graph_module.func_graph_from_py_func(
#     643       name=backwards_graph.name,
#     644       python_func=_backprop_function,
#     645       args=[], kwargs={},
#     646       signature=signature,
#     647       func_graph=backwards_graph)
#     648   backwards_graph_captures = backwards_graph.external_captures
#     649   captures_from_forward = [
#     650       c for c in backwards_graph_captures if
#     651       not isinstance(c, ops.EagerTensor) and c.graph is self._func_graph]
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\func_graph.py:1141, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1138 else:
#    1139   _, original_func = tf_decorator.unwrap(python_func)
# -> 1141 func_outputs = python_func(*func_args, **func_kwargs)
#    1143 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1144 # TensorArrays and `None`s.
#    1145 func_outputs = nest.map_structure(
#    1146     convert, func_outputs, expand_composites=True)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\eager\function.py:633, in _DelayedRewriteGradientFunctions._construct_forward_backward.<locals>._backprop_function(*grad_ys)
#     631 def _backprop_function(*grad_ys):
#     632   with ops.device(None):
# --> 633     return gradients_util._GradientsHelper(  # pylint: disable=protected-access
#     634         trainable_outputs,
#     635         self._func_graph.inputs,
#     636         grad_ys=grad_ys,
#     637         src_graph=self._func_graph)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\gradients_util.py:695, in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     690 with src_graph._original_op(op):
#     691   # pylint: enable=protected-access
#     692   if grad_fn:
#     693     # If grad_fn was found, do not use SymbolicGradient even for
#     694     # functions.
# --> 695     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     696                              lambda: grad_fn(op, *out_grads))
#     697   else:
#     698     # For function call ops, we add a 'SymbolicGradient'
#     699     # node to the graph to compute gradients.
#     700     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     701                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\gradients_util.py:328, in _MaybeCompile(scope, op, func, grad_fn)
#     325     xla_compile = False
#     327 if not xla_compile:
# --> 328   return grad_fn()  # Exit early
#     330 # If the gradients are supposed to be compiled separately, we give them a
#     331 # _XlaScope name that is based on the name_scope of the gradients.  Otherwise
#     332 # they just inherit the existing _XlaScope name, which lets them be merged
#     333 # together with the non-gradient computation.
#     334 if xla_separate_compiled_gradients:
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\gradients_util.py:696, in _GradientsHelper.<locals>.<lambda>()
#     690 with src_graph._original_op(op):
#     691   # pylint: enable=protected-access
#     692   if grad_fn:
#     693     # If grad_fn was found, do not use SymbolicGradient even for
#     694     # functions.
#     695     in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 696                              lambda: grad_fn(op, *out_grads))
#     697   else:
#     698     # For function call ops, we add a 'SymbolicGradient'
#     699     # node to the graph to compute gradients.
#     700     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     701                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\while_v2.py:384, in _WhileGrad(op, *grads)
#     378 # We compute the gradient for the sub-graph between trainable ys and xs
#     379 # with non-None incoming gradients. We later pad the None's to the list of
#     380 # outputs.
#     381 ys, xs, non_none_grads = zip(*[(y, x, grad) for (y, x, grad) in zip(
#     382     body_graph.outputs, body_graph.inputs, grads) if grad is not None])
# --> 384 body_grad_graph, args = _create_grad_func(
#     385     ys, xs, non_none_grads, cond_graph, body_graph,
#     386     util.unique_grad_fn_name(body_graph.name), op, maximum_iterations,
#     387     stateful_parallelism)
#     389 if body_grad_graph.while_op_needs_rewrite:
#     390   # Modify 'op' to output the intermediate accumulators needed by the grad
#     391   # function.
#     392   # NOTE(skyewm): if there are any active sessions, this modification to `op`
#     393   # may make them unrunnable!
#     395   cond_graph.name += "_rewritten"
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\while_v2.py:686, in _create_grad_func(ys, xs, grads, cond_graph, body_graph, name, while_op, maximum_iterations, stateful_parallelism)
#     683 args = [counter, maximum_iterations, total_iters] + list(grads)
#     684 # Note: The returned function does not have `args` in the list of
#     685 # `external_captures`.
# --> 686 grad_func_graph = func_graph_module.func_graph_from_py_func(
#     687     name,
#     688     lambda *args: _grad_fn(ys, xs, args, body_graph),
#     689     args, {},
#     690     func_graph=_WhileBodyGradFuncGraph(name, cond_graph, body_graph,
#     691                                        maximum_iterations, while_op,
#     692                                        body_graph_inputs, body_graph_outputs),
#     693     acd_record_initial_resource_uses=stateful_parallelism)
#     695 # Update the list of outputs with tensors corresponding to the captured
#     696 # tensors. We capture 3 types of tensors when building the grad fn:
#     697 # 1. Accumulators for forward graph intermediates which are not loop
#    (...)
#     700 # 2. Resources, which are output as is.
#     701 # 3. Forward graph loop invariants, which are output as is.
#     702 for external_capture, internal_capture in grad_func_graph.captures:
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\func_graph.py:1141, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1138 else:
#    1139   _, original_func = tf_decorator.unwrap(python_func)
# -> 1141 func_outputs = python_func(*func_args, **func_kwargs)
#    1143 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1144 # TensorArrays and `None`s.
#    1145 func_outputs = nest.map_structure(
#    1146     convert, func_outputs, expand_composites=True)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\while_v2.py:688, in _create_grad_func.<locals>.<lambda>(*args)
#     683 args = [counter, maximum_iterations, total_iters] + list(grads)
#     684 # Note: The returned function does not have `args` in the list of
#     685 # `external_captures`.
#     686 grad_func_graph = func_graph_module.func_graph_from_py_func(
#     687     name,
# --> 688     lambda *args: _grad_fn(ys, xs, args, body_graph),
#     689     args, {},
#     690     func_graph=_WhileBodyGradFuncGraph(name, cond_graph, body_graph,
#     691                                        maximum_iterations, while_op,
#     692                                        body_graph_inputs, body_graph_outputs),
#     693     acd_record_initial_resource_uses=stateful_parallelism)
#     695 # Update the list of outputs with tensors corresponding to the captured
#     696 # tensors. We capture 3 types of tensors when building the grad fn:
#     697 # 1. Accumulators for forward graph intermediates which are not loop
#    (...)
#     700 # 2. Resources, which are output as is.
#     701 # 3. Forward graph loop invariants, which are output as is.
#     702 for external_capture, internal_capture in grad_func_graph.captures:
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\while_v2.py:744, in _grad_fn(ys, xs, args, func_graph)
#     737 grad_ys = args[3:]
#     739 # Build the gradient graph. Note that this builds the gradient computation of
#     740 # func_graph in the current graph, which requires capturing tensors from
#     741 # func_graph. The captured func_graph tensors are resolved to external tensors
#     742 # after the forward While op has been rewritten in _resolve_grad_captures.
#     743 # TODO(srbs): Mark GradientsHelper as public?
# --> 744 grad_outs = gradients_util._GradientsHelper(
#     745     ys, xs, grad_ys=grad_ys, src_graph=func_graph,
#     746     unconnected_gradients="zero")
#     748 # TODO(b/118712257): Handle the case when grad_outs has None's e.g. when there
#     749 # is a tf.StopGradient in the loop body.
#     750 assert all(g is not None for g in grad_outs)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\gradients_util.py:695, in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     690 with src_graph._original_op(op):
#     691   # pylint: enable=protected-access
#     692   if grad_fn:
#     693     # If grad_fn was found, do not use SymbolicGradient even for
#     694     # functions.
# --> 695     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     696                              lambda: grad_fn(op, *out_grads))
#     697   else:
#     698     # For function call ops, we add a 'SymbolicGradient'
#     699     # node to the graph to compute gradients.
#     700     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     701                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\gradients_util.py:328, in _MaybeCompile(scope, op, func, grad_fn)
#     325     xla_compile = False
#     327 if not xla_compile:
# --> 328   return grad_fn()  # Exit early
#     330 # If the gradients are supposed to be compiled separately, we give them a
#     331 # _XlaScope name that is based on the name_scope of the gradients.  Otherwise
#     332 # they just inherit the existing _XlaScope name, which lets them be merged
#     333 # together with the non-gradient computation.
#     334 if xla_separate_compiled_gradients:
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\gradients_util.py:696, in _GradientsHelper.<locals>.<lambda>()
#     690 with src_graph._original_op(op):
#     691   # pylint: enable=protected-access
#     692   if grad_fn:
#     693     # If grad_fn was found, do not use SymbolicGradient even for
#     694     # functions.
#     695     in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 696                              lambda: grad_fn(op, *out_grads))
#     697   else:
#     698     # For function call ops, we add a 'SymbolicGradient'
#     699     # node to the graph to compute gradients.
#     700     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     701                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\list_ops.py:306, in _TensorListSetItemGrad(op, dlist)
#     303 """Gradient function for TensorListSetItem."""
#     304 _, index, item = op.inputs
#     305 list_grad = gen_list_ops.tensor_list_set_item(
# --> 306     dlist, index=index, item=array_ops.zeros_like(item))
#     307 index_grad = None
#     308 element_grad = tensor_list_get_item(
#     309     dlist,
#     310     index,
#     311     element_shape=array_ops.shape(item),
#     312     element_dtype=item.dtype)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\array_ops.py:3075, in zeros_like(tensor, dtype, name, optimize)
#    3038 @tf_export(v1=["zeros_like"])
#    3039 @dispatch.register_unary_elementwise_api
#    3040 @dispatch.add_dispatch_support
#    3041 def zeros_like(tensor, dtype=None, name=None, optimize=True):
#    3042   """Creates a tensor with all elements set to zero.
#    3043
#    3044   See also `tf.zeros`.
#    (...)
#    3073     A `Tensor` with all elements set to zero.
#    3074   """
# -> 3075   return zeros_like_impl(tensor, dtype, name, optimize)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\array_ops.py:2972, in _tag_zeros_tensor.<locals>.wrapped(*args, **kwargs)
#    2971 def wrapped(*args, **kwargs):
# -> 2972   tensor = fun(*args, **kwargs)
#    2973   tensor._is_zeros_tensor = True
#    2974   return tensor
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\array_ops.py:3152, in zeros_like_impl(tensor, dtype, name, optimize)
#    3149   return zeros(
#    3150       shape_internal(tensor, optimize=optimize), dtype=dtype, name=name)
#    3151 else:
# -> 3152   return gen_array_ops.zeros_like(tensor, name=name)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:12747, in zeros_like(x, name)
#   12745     pass  # Add nodes to the TensorFlow graph.
#   12746 # Add nodes to the TensorFlow graph.
# > 12747 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   12748       "ZerosLike", x=x, name=name)
#   12749 _result = _outputs[:]
#   12750 if _execute.must_record_gradient():
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\op_def_library.py:797, in _apply_op_helper(op_type_name, name, **keywords)
#     792 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     793                         if arg.is_ref]
#     794 with _MaybeColocateWith(must_colocate_inputs):
#     795   # Add Op to graph
#     796   # pylint: disable=protected-access
# --> 797   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     798                              name=scope, input_types=input_types,
#     799                              attrs=attr_protos, op_def=op_def)
#     801 # `outputs` is returned as a separate return value so that the output
#     802 # tensors can the `op` per se can be decoupled so that the
#     803 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     804 # for more details.
#     805 outputs = op.outputs
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\while_v2.py:1035, in _WhileBodyGradFuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    1018 if (op_type in optimized_reduction_ops and
#    1019     not util.output_all_intermediates() and
#    1020     all(input.graph is self._forward_graph for input in inputs) and
#    (...)
#    1023     not util.graph_wrapped_for_higher_order_tape_gradients(
#    1024         self._forward_graph)):
#    1025   return self._move_op_to_forward_graph(
#    1026       op_type,
#    1027       inputs,
#    (...)
#    1032       op_def=op_def,
#    1033       compute_device=compute_device)
# -> 1035 return super(_WhileBodyGradFuncGraph, self)._create_op_internal(
#    1036     op_type,
#    1037     inputs,
#    1038     dtypes=dtypes,
#    1039     input_types=input_types,
#    1040     name=name,
#    1041     attrs=attrs,
#    1042     op_def=op_def,
#    1043     compute_device=compute_device)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\func_graph.py:692, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     690   if ctxt is not None and hasattr(ctxt, "AddValue"):
#     691     inp = ctxt.AddValue(inp)
# --> 692   inp = self.capture(inp)
#     693   captured_inputs.append(inp)
#     694 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     695     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     696     compute_device)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\func_graph.py:759, in FuncGraph.capture(self, tensor, name, shape)
#     749       raise errors.InaccessibleTensorError(
#     750           f"{tensor!r} is out of scope and cannot be used here. Use return "
#     751           "values, explicit Python locals or TensorFlow collections to "
#    (...)
#     756           f"The tensor {tensor!r} cannot be accessed from {self}, because "
#     757           f"it was defined in {tensor.graph}, which is out of scope.")
#     758     inner_graph = inner_graph.outer_graph
# --> 759   return self._capture_helper(tensor, name)
#     760 return tensor
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\while_v2.py:1198, in _WhileBodyGradFuncGraph._capture_helper(self, tensor, name)
#    1196 with self._forward_graph.outer_graph.as_default():
#    1197   with util.clear_control_inputs():
# -> 1198     tensor_list = list_ops.empty_tensor_list(
#    1199         element_dtype=tensor.dtype,
#    1200         element_shape=tensor.shape,
#    1201         max_num_elements=self._maximum_iterations,
#    1202         name=_build_accumulator_name(tensor))
#    1203 self.extra_inputs.append(tensor_list)
#    1205 # Push the intermediate tensor to the tensor list. This captures
#    1206 # `tensor_list`.
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\list_ops.py:54, in empty_tensor_list(element_shape, element_dtype, max_num_elements, name)
#      51 if max_num_elements is None:
#      52   max_num_elements = -1
# ---> 54 return gen_list_ops.empty_tensor_list(
#      55     element_shape=_build_element_shape(element_shape),
#      56     element_dtype=element_dtype,
#      57     max_num_elements=max_num_elements,
#      58     name=name)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\ops\gen_list_ops.py:62, in empty_tensor_list(element_shape, max_num_elements, element_dtype, name)
#      60 # Add nodes to the TensorFlow graph.
#      61 element_dtype = _execute.make_type(element_dtype, "element_dtype")
# ---> 62 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#      63       "EmptyTensorList", element_shape=element_shape,
#      64                          max_num_elements=max_num_elements,
#      65                          element_dtype=element_dtype, name=name)
#      66 _result = _outputs[:]
#      67 if _execute.must_record_gradient():
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\op_def_library.py:779, in _apply_op_helper(op_type_name, name, **keywords)
#     777 with g.as_default(), ops.name_scope(name) as scope:
#     778   if fallback:
# --> 779     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     780                            keywords, default_type_attr_map, attrs, inputs,
#     781                            input_types)
#     782     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     783                            default_type_attr_map, attrs)
#     784     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\op_def_library.py:552, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     546       values = ops.convert_to_tensor(
#     547           values,
#     548           name=input_arg.name,
#     549           as_ref=input_arg.is_ref,
#     550           preferred_dtype=default_dtype)
#     551   else:
# --> 552     values = ops.convert_to_tensor(
#     553         values,
#     554         name=input_arg.name,
#     555         dtype=dtype,
#     556         as_ref=input_arg.is_ref,
#     557         preferred_dtype=default_dtype)
#     558 except TypeError as err:
#     559   if dtype is None:
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\ops.py:1640, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1631       raise RuntimeError(
#    1632           _add_error_prefix(
#    1633               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1636               f"actual = {ret.dtype.base_dtype.name}",
#    1637               name=name))
#    1639 if ret is None:
# -> 1640   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1642 if ret is NotImplemented:
#    1643   continue
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\constant_op.py:343, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     340 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     292 if op_callbacks.should_invoke_op_callbacks():
#     293   # TODO(b/147670703): Once the special-op creation code paths
#     294   # are unified. Remove this `if` block.
#     295   callback_outputs = op_callbacks.invoke_op_callbacks(
#     296       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\func_graph.py:694, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     692   inp = self.capture(inp)
#     693   captured_inputs.append(inp)
# --> 694 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     695     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     696     compute_device)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\ops.py:3754, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3751 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3752 # Session.run call cannot occur between creating and mutating the op.
#    3753 with self._mutation_lock():
# -> 3754   ret = Operation(
#    3755       node_def,
#    3756       self,
#    3757       inputs=inputs,
#    3758       output_types=dtypes,
#    3759       control_inputs=control_inputs,
#    3760       input_types=input_types,
#    3761       original_op=self._default_original_op,
#    3762       op_def=op_def)
#    3763   self._create_op_helper(ret, compute_device=compute_device)
#    3764 return ret
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\ops.py:2129, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2127   if op_def is None:
#    2128     op_def = self._graph._get_op_def(node_def.op)
# -> 2129   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2130                             control_input_ops, op_def)
#    2131   name = compat.as_str(node_def.name)
#    2133 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\honsu\anaconda3\envs\python39\lib\site-packages\tensorflow\python\framework\ops.py:1960, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1956   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1957                                          serialized)
#    1959 try:
# -> 1960   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1961 except errors.InvalidArgumentError as e:
#    1962   # Convert to ValueError for backwards compatibility.
#    1963   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
pd.concat(ALL_METRICS, axis=0)
# Out:
# cv_idx                  2.000000
# train_0               400.000000
# train_1                21.000000
# train_2                38.000000
# train_y                 2.000000
# test_size             100.000000
# rnn_layers              5.000000
# rnn_neurons            64.000000
# dnn_layers              5.000000
# dnn_neurons            64.000000
# learning_rate           0.001000
# window_size            10.000000
# regularizer_input            NaN
# regularizer_hidden           NaN
# regularizer_bias             NaN
# training_time           0.173600
# test_loss               0.223039
# accuracy               95.600000
# precision_0            99.380000
# precision_1             7.500000
# recall_0               96.162000
# recall_1               40.000000
# f1_0                   97.722000
# f1_1                   12.444000
# Name: 8, dtype: float64

# %%
model_path
# Out:
# './models/SELECTED_WITH_SEQ_L21_0.00001_L21_0.00001_KFOLD_3_64_3_64_Adam_0.001_None_None_None_10_(500, 21, 41)/1.h5'

# %%
os.path.exists(model_path)
# Out:
# True
